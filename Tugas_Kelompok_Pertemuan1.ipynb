# %% [markdown]
# <a href="https://colab.research.google.com/github/Alerakha/05_Aleron-Tsaqif-Rakha_PCVK_Ganjil_2024/blob/main/Tugas_Kelompok_Pertemuan1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **TUGAS KELOMPOK**
# 1. Akses file image lokal (KTP/SIM) dan tampilkan menggunakan OpenCV dan Matplotlib
# 2. Identifikasi kenapa menggunakan konversi warna BGR2RGB pada matplotlib dan tanpa
# konversi pada opencv
# 3. Tutup tiap bagian tertentu dari kartu identitas tersebut. Kelompok 1 tutup bagian nomor
# NIK dan nama. Kelompok 2 tutup bagian TTL dan Jenis Kelamin. Kelompok 3 tutup bagian
# Gol. Darah dan TTD. Kelompok 4 tutup bagian Alamat dan Kecamatan. Kelompok 5 tutup
# bagian Agama dan Status Kawin. Kelompok 6 tutup Pekerjaan dan kewarganegaraan.
# Kelompok 7 tutup bagian berlaku hingga dan foto. Kelompok 8 tutup bagian kabupaten
# dan tanggal dikeluarkan KTP yang ada dibagian bawah foto. Kelompok 9 tutup bagian
# nama propinsi dan kabupaten di bagian paling atas KTP. Kelompok 10 tutup bagian RT/RW
# dan Kel/desa. Tutup menggunakan 2 kotak warna yang berbeda. Tidak boleh
# menggunakan fungsi rectangle openCV, fungsi ini akan dipelajari pada pertemuan 2.

# %% [markdown]
# **JAWAB**
# 1. Untuk menampilkan image dengan OpenCV menggunakan ``` cv.imshow(#nama_image) ``` atau menggunakan ``` plt.show(#nama_image) ``` untuk Matplotlib. Namun pada google colab, ```cv.imshow()``` tidak dapat digunakan dan diganti dengan ```cv_imshow()``` ini dikarenakan fungsi show dari OpenCV tidak kompatibel dengan google colab.
# 2. Matplotlib tidak memerlukan konversi dari BGR ke RGB, karena warna default untuk memproses gambar adalah RGB. Sedangkan opencv perlu menggunakan konversi BGR ke RGB dengan ``` cv.COLOR_BGR2RGB ``` karena format warna default opencv untuk memproses gambar adalah BGR
# 3. Tugas kelompok 3

# %%
import numpy as np
import cv2 as cv
from PIL import Image
from google.colab.patches import cv2_imshow as cv_imshow
import matplotlib.pylab as plt
import matplotlib.patches as patches

img_pil = Image.open('KTP.jpg')
img = np.array(img_pil)
img = cv.resize(img, (0,0), fx=0.5, fy=0.5)
fig, ax = plt.subplots()
image_rgb = cv.cvtColor(img, cv.COLOR_BGR2RGB)


# img = cv.rectangle(img, (513,165), (535,185), (255,255,255), -1)
# img = cv.rectangle(img, (600,385), (765,480), (255,255,255), -1)

# img = cv.rectangle(img, (260,84), (282,93), (255,255,255), -1)
# img = cv.rectangle(img, (300,193), (382,240), (255,255,255), -1)
final_frame = cv.hconcat((img, image_rgb))
print("Matplotlib tanpa BGR to RGB")
plt.imshow(img)
plt.show()

rect1 = patches.Rectangle((513, 165), 40, 25, linewidth=1, edgecolor='black', facecolor='white')
rect2 = patches.Rectangle((600, 385), 170, 85, linewidth=3, edgecolor='black', facecolor='yellow')

ax = plt.gca()
ax.add_patch(rect1)
ax.add_patch(rect2)
print("OpenCV: kiri tanpa BGR to RGB, kanan dengan BGR to RGB")
cv_imshow(final_frame)
plt.imshow(img_pil)
plt.axis('off')
# plt.show()

# cv.imshow('image', img)
# Out:
# Matplotlib tanpa BGR to RGB
# OpenCV: kiri tanpa BGR to RGB, kanan dengan BGR to RGB
# <PIL.Image.Image image mode=RGB size=800x244>
# (-0.5, 799.5, 487.5, -0.5)
