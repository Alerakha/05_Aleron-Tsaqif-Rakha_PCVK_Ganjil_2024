# %% [markdown]
# <a href="https://colab.research.google.com/github/Alerakha/05_Aleron-Tsaqif-Rakha_PCVK_Ganjil_2024/blob/main/Tugas_Kelompok_Pertemuan2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title Tugas Kelompok.2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow
import cv2 as cv
# cv.rectangle(img,  pt1=(190,140), pt2=(450,160), color=(230,175,0), thickness=-1)
# cv.rectangle(img, pt1=(190,165), pt2=(290,185), color=(103,175,89), thickness=-1)

img = cv.imread('KTP.jpg')
img_rectangle = img[140:160,190:450]
img_rectangle [:,:,1]=0
img_rectangle [:,:,2]=0

img_rect2 = img[165:185,190:290] #Koordinat img[x1:x2,y1:y2] tidak bisa dibalik
img_rect2 [:,:,0]=0
img_rect2 [:,:,1]=0

img = cv.cvtColor(img, cv.COLOR_BGR2RGB)

plt.imshow(img)
plt.show()
